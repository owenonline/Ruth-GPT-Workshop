# %%
import requests
from pprint import pprint

#https://mm-gpt-chat-prod.azurewebsites.net
resp = requests.post("http://127.0.0.1:5000/chat", json={"matter_id": "12766106", "question": "Who is the plaintiff in this case?", "chat_history": ""}).json()
pprint(resp)

resp = requests.post("http://127.0.0.1:5000/chat", json={"matter_id": "12766106", "question": "What happened to him?", "chat_history": resp['updated_chat_history']}).json()
pprint(resp)
# Out:
# {'agent_response': 'The plaintiff in this case is Robert Silverence.',
#  'sources': {'litify metadata': 'https://forthepeople--uat.sandbox.my.salesforce.com/lightning/r/litify_pm__Matter__c/a1n3c00000AGC7zAAH/view'},
#  'updated_chat_history': '0b096fa8-3c92-4a95-90ab-328ecaeccc62'}
# {'agent_response': 'Robert Silverence was walking in the garden section of a '
#                    'Home Depot store when he slipped on some plastic on the '
#                    'ground. He fell forward, landing on his hands and knees. '
#                    'As a result of the fall, he sustained several injuries, '
#                    'including significant pain and a gash on his right knee, '
#                    'swelling in the calf of his right leg, and scratches and '
#                    'pain in his left knee. He sought immediate medical '
#                    'attention at a hospital.',
#  'sources': {'client cares': 'https://forthepeople--uat.sandbox.my.salesforce.com/lightning/r/Client_Care__c/aGs3c000000Q6oSCAS/view',
#              'litify metadata': 'https://forthepeople--uat.sandbox.my.salesforce.com/lightning/r/litify_pm__Matter__c/a1n3c00000AGC7zAAH/view'},
#  'updated_chat_history': '0b096fa8-3c92-4a95-90ab-328ecaeccc62'}

# %% [markdown]
# # Part 1: Data Gathering
# The first part of the vectorstore QA agent is creating the vector store. To do this, we scrape the documentation we want the agent to have access to and put it in a vector store. In this example, we used chroma, which allows you to create local vector stores, but for Morgan and Morgan we used a hosted version called Pinecone capable of hosting enormous amounts of data.

# %%
from bs4 import BeautifulSoup as Soup
from langchain.document_loaders.recursive_url_loader import RecursiveUrlLoader
import pickle

urls = ["https://docs.manim.community/en/stable/"]

# loader = RecursiveUrlLoader(url="https://docs.manim.community/en/stable/", max_depth=3, extractor=lambda x: Soup(x, "html.parser").text)
# docs = loader.load()

with open("manim_docs.pkl", "rb") as f:
    docs = pickle.load(f)

# %%
from pprint import pprint
print(f"{len(docs)} documents loaded")
pprint(docs[8].page_content)
# Out:
# 433 documents loaded
# ('\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'JSONFormatter - Manim Community v0.17.3\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Contents\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Menu\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Expand\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Light mode\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Dark mode\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Auto light/dark mode\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Hide navigation sidebar\n'
#  '\n'
#  '\n'
#  'Hide table of contents sidebar\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Toggle site navigation sidebar\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Manim Community v0.17.3\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Toggle Light / Dark / Auto color theme\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Toggle table of contents sidebar\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Manim Community v0.17.3\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Example Gallery\n'
#  'InstallationToggle child pages in navigation\n'
#  'Conda\n'
#  'Windows\n'
#  'macOS\n'
#  'Linux\n'
#  'Docker\n'
#  'Jupyter Notebooks\n'
#  '\n'
#  '\n'
#  'Tutorials & GuidesToggle child pages in navigation\n'
#  'TutorialsToggle child pages in navigation\n'
#  'Quickstart\n'
#  'Manim’s Output Settings\n'
#  'Manim’s building blocks\n'
#  '\n'
#  '\n'
#  'Thematic GuidesToggle child pages in navigation\n'
#  'Configuration\n'
#  'A deep dive into Manim’s internals\n'
#  'Rendering Text and Formulas\n'
#  'Adding Voiceovers to Videos\n'
#  '\n'
#  '\n'
#  'Frequently Asked QuestionsToggle child pages in navigation\n'
#  'FAQ: General Usage\n'
#  'FAQ: Getting Help\n'
#  'FAQ: Installation\n'
#  'Where can I learn more about Manim’s internal structure?\n'
#  'FAQ: OpenGL rendering\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Reference ManualToggle child pages in navigation\n'
#  'AnimationsToggle child pages in navigation\n'
#  'animationToggle child pages in navigation\n'
#  'Animation\n'
#  'Wait\n'
#  '\n'
#  '\n'
#  'changingToggle child pages in navigation\n'
#  'AnimatedBoundary\n'
#  'TracedPath\n'
#  '\n'
#  '\n'
#  'compositionToggle child pages in navigation\n'
#  'AnimationGroup\n'
#  'LaggedStart\n'
#  'LaggedStartMap\n'
#  'Succession\n'
#  '\n'
#  '\n'
#  'creationToggle child pages in navigation\n'
#  'AddTextLetterByLetter\n'
#  'AddTextWordByWord\n'
#  'Create\n'
#  'DrawBorderThenFill\n'
#  'RemoveTextLetterByLetter\n'
#  'ShowIncreasingSubsets\n'
#  'ShowPartial\n'
#  'ShowSubmobjectsOneByOne\n'
#  'SpiralIn\n'
#  'Uncreate\n'
#  'Unwrite\n'
#  'Write\n'
#  '\n'
#  '\n'
#  'fadingToggle child pages in navigation\n'
#  'FadeIn\n'
#  'FadeOut\n'
#  '\n'
#  '\n'
#  'growingToggle child pages in navigation\n'
#  'GrowArrow\n'
#  'GrowFromCenter\n'
#  'GrowFromEdge\n'
#  'GrowFromPoint\n'
#  'SpinInFromNothing\n'
#  '\n'
#  '\n'
#  'indicationToggle child pages in navigation\n'
#  'ApplyWave\n'
#  'Circumscribe\n'
#  'Flash\n'
#  'FocusOn\n'
#  'Indicate\n'
#  'ShowCreationThenFadeOut\n'
#  'ShowPassingFlash\n'
#  'ShowPassingFlashWithThinningStrokeWidth\n'
#  'Wiggle\n'
#  '\n'
#  '\n'
#  'movementToggle child pages in navigation\n'
#  'ComplexHomotopy\n'
#  'Homotopy\n'
#  'MoveAlongPath\n'
#  'PhaseFlow\n'
#  'SmoothedVectorizedHomotopy\n'
#  '\n'
#  '\n'
#  'numbersToggle child pages in navigation\n'
#  'ChangeDecimalToValue\n'
#  'ChangingDecimal\n'
#  '\n'
#  '\n'
#  'rotationToggle child pages in navigation\n'
#  'Rotate\n'
#  'Rotating\n'
#  '\n'
#  '\n'
#  'specializedToggle child pages in navigation\n'
#  'Broadcast\n'
#  '\n'
#  '\n'
#  'speedmodifierToggle child pages in navigation\n'
#  'ChangeSpeed\n'
#  '\n'
#  '\n'
#  'transformToggle child pages in navigation\n'
#  'ApplyComplexFunction\n'
#  'ApplyFunction\n'
#  'ApplyMatrix\n'
#  'ApplyMethod\n'
#  'ApplyPointwiseFunction\n'
#  'ApplyPointwiseFunctionToCenter\n'
#  'ClockwiseTransform\n'
#  'CounterclockwiseTransform\n'
#  'CyclicReplace\n'
#  'FadeToColor\n'
#  'FadeTransform\n'
#  'FadeTransformPieces\n'
#  'MoveToTarget\n'
#  'ReplacementTransform\n'
#  'Restore\n'
#  'ScaleInPlace\n'
#  'ShrinkToCenter\n'
#  'Swap\n'
#  'Transform\n'
#  'TransformAnimations\n'
#  'TransformFromCopy\n'
#  '\n'
#  '\n'
#  'transform_matching_partsToggle child pages in navigation\n'
#  'TransformMatchingAbstractBase\n'
#  'TransformMatchingShapes\n'
#  'TransformMatchingTex\n'
#  '\n'
#  '\n'
#  'updatersToggle child pages in navigation\n'
#  'mobject_update_utils\n'
#  'updateToggle child pages in navigation\n'
#  'MaintainPositionRelativeTo\n'
#  'UpdateFromAlphaFunc\n'
#  'UpdateFromFunc\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'CamerasToggle child pages in navigation\n'
#  'cameraToggle child pages in navigation\n'
#  'BackgroundColoredVMobjectDisplayer\n'
#  'Camera\n'
#  '\n'
#  '\n'
#  'mapping_cameraToggle child pages in navigation\n'
#  'MappingCamera\n'
#  'OldMultiCamera\n'
#  'SplitScreenCamera\n'
#  '\n'
#  '\n'
#  'moving_cameraToggle child pages in navigation\n'
#  'MovingCamera\n'
#  '\n'
#  '\n'
#  'multi_cameraToggle child pages in navigation\n'
#  'MultiCamera\n'
#  '\n'
#  '\n'
#  'three_d_cameraToggle child pages in navigation\n'
#  'ThreeDCamera\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'ConfigurationToggle child pages in navigation\n'
#  '_config\n'
#  'utilsToggle child pages in navigation\n'
#  'ManimConfig\n'
#  'ManimFrame\n'
#  '\n'
#  '\n'
#  'logger_utilsToggle child pages in navigation\n'
#  'JSONFormatter\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'MobjectsToggle child pages in navigation\n'
#  'frameToggle child pages in navigation\n'
#  'FullScreenRectangle\n'
#  'ScreenRectangle\n'
#  '\n'
#  '\n'
#  'geometryToggle child pages in navigation\n'
#  'arcToggle child pages in navigation\n'
#  'AnnotationDot\n'
#  'AnnularSector\n'
#  'Annulus\n'
#  'Arc\n'
#  'ArcBetweenPoints\n'
#  'ArcPolygon\n'
#  'ArcPolygonFromArcs\n'
#  'Circle\n'
#  'CubicBezier\n'
#  'CurvedArrow\n'
#  'CurvedDoubleArrow\n'
#  'Dot\n'
#  'Ellipse\n'
#  'LabeledDot\n'
#  'Sector\n'
#  'TipableVMobject\n'
#  '\n'
#  '\n'
#  'boolean_opsToggle child pages in navigation\n'
#  'Difference\n'
#  'Exclusion\n'
#  'Intersection\n'
#  'Union\n'
#  '\n'
#  '\n'
#  'lineToggle child pages in navigation\n'
#  'Angle\n'
#  'Arrow\n'
#  'DashedLine\n'
#  'DoubleArrow\n'
#  'Elbow\n'
#  'Line\n'
#  'RightAngle\n'
#  'TangentLine\n'
#  'Vector\n'
#  '\n'
#  '\n'
#  'polygramToggle child pages in navigation\n'
#  'Cutout\n'
#  'Polygon\n'
#  'Polygram\n'
#  'Rectangle\n'
#  'RegularPolygon\n'
#  'RegularPolygram\n'
#  'RoundedRectangle\n'
#  'Square\n'
#  'Star\n'
#  'Triangle\n'
#  '\n'
#  '\n'
#  'shape_matchersToggle child pages in navigation\n'
#  'BackgroundRectangle\n'
#  'Cross\n'
#  'SurroundingRectangle\n'
#  'Underline\n'
#  '\n'
#  '\n'
#  'tipsToggle child pages in navigation\n'
#  'ArrowCircleFilledTip\n'
#  'ArrowCircleTip\n'
#  'ArrowSquareFilledTip\n'
#  'ArrowSquareTip\n'
#  'ArrowTip\n'
#  'ArrowTriangleFilledTip\n'
#  'ArrowTriangleTip\n'
#  'StealthTip\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'graphToggle child pages in navigation\n'
#  'DiGraph\n'
#  'GenericGraph\n'
#  'Graph\n'
#  '\n'
#  '\n'
#  'graphingToggle child pages in navigation\n'
#  'coordinate_systemsToggle child pages in navigation\n'
#  'Axes\n'
#  'ComplexPlane\n'
#  'CoordinateSystem\n'
#  'NumberPlane\n'
#  'PolarPlane\n'
#  'ThreeDAxes\n'
#  '\n'
#  '\n'
#  'functionsToggle child pages in navigation\n'
#  'FunctionGraph\n'
#  'ImplicitFunction\n'
#  'ParametricFunction\n'
#  '\n'
#  '\n'
#  'number_lineToggle child pages in navigation\n'
#  'NumberLine\n'
#  'UnitInterval\n'
#  '\n'
#  '\n'
#  'probabilityToggle child pages in navigation\n'
#  'BarChart\n'
#  'SampleSpace\n'
#  '\n'
#  '\n'
#  'scaleToggle child pages in navigation\n'
#  'LinearBase\n'
#  'LogBase\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'logoToggle child pages in navigation\n'
#  'ManimBanner\n'
#  '\n'
#  '\n'
#  'matrixToggle child pages in navigation\n'
#  'DecimalMatrix\n'
#  'IntegerMatrix\n'
#  'Matrix\n'
#  'MobjectMatrix\n'
#  '\n'
#  '\n'
#  'mobjectToggle child pages in navigation\n'
#  'Group\n'
#  'Mobject\n'
#  '\n'
#  '\n'
#  'svgToggle child pages in navigation\n'
#  'braceToggle child pages in navigation\n'
#  'ArcBrace\n'
#  'Brace\n'
#  'BraceBetweenPoints\n'
#  'BraceLabel\n'
#  'BraceText\n'
#  '\n'
#  '\n'
#  'svg_mobjectToggle child pages in navigation\n'
#  'SVGMobject\n'
#  'VMobjectFromSVGPath\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'tableToggle child pages in navigation\n'
#  'DecimalTable\n'
#  'IntegerTable\n'
#  'MathTable\n'
#  'MobjectTable\n'
#  'Table\n'
#  '\n'
#  '\n'
#  'textToggle child pages in navigation\n'
#  'code_mobjectToggle child pages in navigation\n'
#  'Code\n'
#  '\n'
#  '\n'
#  'numbersToggle child pages in navigation\n'
#  'DecimalNumber\n'
#  'Integer\n'
#  'Variable\n'
#  '\n'
#  '\n'
#  'tex_mobjectToggle child pages in navigation\n'
#  'BulletedList\n'
#  'MathTex\n'
#  'SingleStringMathTex\n'
#  'Tex\n'
#  'Title\n'
#  '\n'
#  '\n'
#  'text_mobjectToggle child pages in navigation\n'
#  'MarkupText\n'
#  'Paragraph\n'
#  'Text\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'three_dToggle child pages in navigation\n'
#  'polyhedraToggle child pages in navigation\n'
#  'Dodecahedron\n'
#  'Icosahedron\n'
#  'Octahedron\n'
#  'Polyhedron\n'
#  'Tetrahedron\n'
#  '\n'
#  '\n'
#  'three_d_utils\n'
#  'three_dimensionsToggle child pages in navigation\n'
#  'Arrow3D\n'
#  'Cone\n'
#  'Cube\n'
#  'Cylinder\n'
#  'Dot3D\n'
#  'Line3D\n'
#  'Prism\n'
#  'Sphere\n'
#  'Surface\n'
#  'ThreeDVMobject\n'
#  'Torus\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'typesToggle child pages in navigation\n'
#  'image_mobjectToggle child pages in navigation\n'
#  'AbstractImageMobject\n'
#  'ImageMobject\n'
#  'ImageMobjectFromCamera\n'
#  '\n'
#  '\n'
#  'point_cloud_mobjectToggle child pages in navigation\n'
#  'Mobject1D\n'
#  'Mobject2D\n'
#  'PGroup\n'
#  'PMobject\n'
#  'Point\n'
#  'PointCloudDot\n'
#  '\n'
#  '\n'
#  'vectorized_mobjectToggle child pages in navigation\n'
#  'CurvesAsSubmobjects\n'
#  'DashedVMobject\n'
#  'VDict\n'
#  'VGroup\n'
#  'VMobject\n'
#  'VectorizedPoint\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'utils\n'
#  'value_trackerToggle child pages in navigation\n'
#  'ComplexValueTracker\n'
#  'ValueTracker\n'
#  '\n'
#  '\n'
#  'vector_fieldToggle child pages in navigation\n'
#  'ArrowVectorField\n'
#  'StreamLines\n'
#  'VectorField\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'ScenesToggle child pages in navigation\n'
#  'moving_camera_sceneToggle child pages in navigation\n'
#  'MovingCameraScene\n'
#  '\n'
#  '\n'
#  'sectionToggle child pages in navigation\n'
#  'DefaultSectionType\n'
#  'Section\n'
#  '\n'
#  '\n'
#  'sceneToggle child pages in navigation\n'
#  'RerunSceneHandler\n'
#  'Scene\n'
#  '\n'
#  '\n'
#  'scene_file_writerToggle child pages in navigation\n'
#  'SceneFileWriter\n'
#  '\n'
#  '\n'
#  'three_d_sceneToggle child pages in navigation\n'
#  'SpecialThreeDScene\n'
#  'ThreeDScene\n'
#  '\n'
#  '\n'
#  'vector_space_sceneToggle child pages in navigation\n'
#  'LinearTransformationScene\n'
#  'VectorScene\n'
#  '\n'
#  '\n'
#  'zoomed_sceneToggle child pages in navigation\n'
#  'ZoomedScene\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Utilities and other modulesToggle child pages in navigation\n'
#  'constantsToggle child pages in navigation\n'
#  'LineJointType\n'
#  'RendererType\n'
#  '\n'
#  '\n'
#  'bezier\n'
#  'colorToggle child pages in navigation\n'
#  'Colors\n'
#  '\n'
#  '\n'
#  'commands\n'
#  'config_opsToggle child pages in navigation\n'
#  'DictAsObject\n'
#  '\n'
#  '\n'
#  'deprecation\n'
#  'debug\n'
#  'docbuild\n'
#  'hashing\n'
#  'ipython_magicToggle child pages in navigation\n'
#  'ManimMagic\n'
#  '\n'
#  '\n'
#  'images\n'
#  'iterables\n'
#  'paths\n'
#  'rate_functions\n'
#  'simple_functions\n'
#  'sounds\n'
#  'space_ops\n'
#  'texToggle child pages in navigation\n'
#  'TexTemplate\n'
#  'TexTemplateFromFile\n'
#  '\n'
#  '\n'
#  'tex_templatesToggle child pages in navigation\n'
#  'TexFontTemplates\n'
#  'TexTemplateLibrary\n'
#  '\n'
#  '\n'
#  'tex_file_writing\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Plugins\n'
#  'ChangelogToggle child pages in navigation\n'
#  'v0.17.3\n'
#  'v0.17.2\n'
#  'v0.17.1\n'
#  'v0.17.0\n'
#  'v0.16.0\n'
#  'v0.15.2\n'
#  'v0.15.1\n'
#  'v0.15.0\n'
#  'v0.14.0\n'
#  'v0.13.1\n'
#  'v0.13.0\n'
#  'v0.12.0\n'
#  'v0.11.0\n'
#  'v0.10.0\n'
#  'v0.9.0\n'
#  'v0.8.0\n'
#  'v0.7.0\n'
#  'v0.6.0\n'
#  'v0.5.0\n'
#  'v0.4.0\n'
#  'v0.3.0\n'
#  'v0.2.0\n'
#  'v0.1.1\n'
#  'v0.1.0\n'
#  '\n'
#  '\n'
#  'ContributingToggle child pages in navigation\n'
#  'Manim Development Process\n'
#  'Adding Docstrings\n'
#  'Adding References\n'
#  'Adding Examples\n'
#  'Adding Typings\n'
#  'Adding Admonitions\n'
#  'Adding Tests\n'
#  'Improving performance\n'
#  'Internationalization\n'
#  '\n'
#  '\n'
#  'Code of Conduct\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\xa0\n'
#  '    v: stable\n'
#  '  \n'
#  '\n'
#  '\n'
#  'Versions\n'
#  'latest\n'
#  'stable\n'
#  'v0.17.3\n'
#  'v0.17.2\n'
#  'v0.17.1\n'
#  'v0.17.0\n'
#  'v0.16.0.post0\n'
#  'v0.16.0\n'
#  'v0.15.2\n'
#  'v0.15.1\n'
#  'v0.15.0\n'
#  'v0.14.0\n'
#  'v0.13.1\n'
#  'v0.13.0\n'
#  'v0.12.0\n'
#  'v0.11.0\n'
#  'v0.10.0\n'
#  'v0.9.0\n'
#  'v0.8.0\n'
#  'v0.7.0\n'
#  'v0.6.0\n'
#  'v0.5.0\n'
#  'v0.4.0\n'
#  'v0.3.0\n'
#  'v0.2.0\n'
#  'v0.1.1\n'
#  'v0.1.0\n'
#  '\n'
#  '\n'
#  'Downloads\n'
#  '\n'
#  '\n'
#  'On Read the Docs\n'
#  '\n'
#  'Project Home\n'
#  '\n'
#  '\n'
#  'Builds\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Back to top\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Toggle Light / Dark / Auto color theme\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Toggle table of contents sidebar\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'JSONFormatter#\n'
#  'Qualified name: manim.\\_config.logger\\_utils.JSONFormatter\n'
#  '\n'
#  '\n'
#  "class JSONFormatter(fmt=None, datefmt=None, style='%', "
#  'validate=True)[source]#\n'
#  'Bases: Formatter\n'
#  'A formatter that outputs logs in a custom JSON format.\n'
#  'This class is used internally for testing purposes.\n'
#  'Initialize the formatter with specified format strings.\n'
#  'Initialize the formatter either with the specified format string, or a\n'
#  'default as described above. Allow for specialized date formatting with\n'
#  'the optional datefmt argument. If datefmt is omitted, you get an\n'
#  'ISO8601-like (or RFC 3339-like) format.\n'
#  'Use a style parameter of ‘%’, ‘{’ or ‘$’ to specify that you want to\n'
#  'use one of %-formatting, str.format() ({}) formatting or\n'
#  'string.Template formatting in your format string.\n'
#  '\n'
#  'Changed in version 3.2: Added the style parameter.\n'
#  '\n'
#  'Methods\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'format\n'
#  'Format the record in a custom JSON format.\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Attributes\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'default_msec_format\n'
#  '\n'
#  '\n'
#  'default_time_format\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'format(record)[source]#\n'
#  'Format the record in a custom JSON format.\n'
#  '\n'
#  'Parameters\n'
#  'record (dict) – \n'
#  '\n'
#  'Return type\n'
#  'str\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Next\n'
#  '\n'
#  'Mobjects\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  'Previous\n'
#  '\n'
#  'logger_utils\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '                Copyright © 2020-2022, The Manim Community Dev Team\n'
#  '            \n'
#  "            Made with Sphinx and @pradyunsg's\n"
#  '            \n'
#  '            Furo\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n')

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from dotenv import load_dotenv

load_dotenv()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
split_docs = text_splitter.split_documents(docs)

db = Chroma.from_documents(split_docs, embedding=OpenAIEmbeddings())

# %% [markdown]
# # Part 2: QA Agent
# Now that we have our documentation in a vector store, we can use LangChain to create an agent capable of answering questions about these documents

# %%
from langchain.chat_models import ChatOpenAI

chat = ChatOpenAI(model="gpt-4")

# %%
from langchain.pydantic_v1 import BaseModel, Field, validator
from langchain.prompts import PromptTemplate
from langchain.output_parsers import PydanticOutputParser, OutputFixingParser

class DocsResponse(BaseModel):
    explanation: str = Field(description="The explanation answering the user's question")
    example: str = Field(description="A code example to support the explanation")

parser = PydanticOutputParser(pydantic_object=DocsResponse)
fixing_parser = OutputFixingParser.from_llm(parser=parser, llm=chat)

prompt_template = """You are an AI assistant helping a user with a question about writing code with Manim. Answer the user's question using the documentation below and provide a code example to support your explanation.

FORMAT: {format_instructions}

DOCUMENTATION:
{context}

REQUEST: 
{question}

Answer the user's question according to the FORMAT above:"""

PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"], partial_variables={"format_instructions": parser.get_format_instructions()}
)

chain_type_kwargs = {"prompt": PROMPT}

# %%
from langchain.chains import RetrievalQA

qa_chain = RetrievalQA.from_chain_type(llm=ChatOpenAI(model="gpt-4"), chain_type="stuff", retriever=db.as_retriever(), chain_type_kwargs=chain_type_kwargs, return_source_documents=True)

answer = qa_chain({"query": "How can I animate a circle in Manim?"})

parsed_answer = fixing_parser.parse(answer['result'])

print(parsed_answer.explanation)
pprint(parsed_answer.example)
print(answer['source_documents'])
# Out:
# In Manim, you can animate a circle using the `animate` method. This method allows you to apply various transformations to the circle, such as rotation, coloring, flipping, and shifting. To animate a circle, first create an instance of the Circle class, then use the `animate` method along with the transformation you want to apply. The `self.play` function is used to display the animation.
# ('from manim import *\n'
#  '\n'
#  '\n'
#  'class AnimateCircle(Scene):\n'
#  '    def construct(self):\n'
#  '        circle = Circle()  # create a circle\n'
#  '        circle.set_fill(PINK, opacity=0.5)  # set the color and '
#  'transparency\n'
#  '        self.play(Create(circle))  # show the circle on screen\n'
#  '        self.play(circle.animate.rotate(PI / 4))  # rotate the circle\n'
#  '        self.play(circle.animate.set_fill(RED, opacity=0.5))  # change the '
#  'color of the circle\n'
#  '\n'
#  '\n'
#  '# To render the animation, run the following command in the command line:\n'
#  '# manim -pql scene.py AnimateCircle')
# [Document(page_content='Open a text editor, such as Notepad. Copy the following code snippet into the window:\n\nfrom manim import *\n\n\nclass CreateCircle(Scene):\n    def construct(self):\n        circle = Circle()  # create a circle\n        circle.set_fill(PINK, opacity=0.5)  # set the color and transparency\n        self.play(Create(circle))  # show the circle on screen\n\n\n\nSave the code snippet into your project folder with the name scene.py.\n\nproject/\n└─scene.py\n\n\n3. Open the command line, navigate to your project folder, and execute\nthe following command:\nmanim -pql scene.py CreateCircle\n\n\nManim will output rendering information, then create an MP4 file.\nYour default movie player will play the MP4 file, displaying the following animation.', metadata={'description': 'Overview: This quickstart guide will lead you through creating a sample project using Manim: an animation engine for precise programmatic animations. First, you will use a command line interface to...', 'language': 'en', 'source': 'https://docs.manim.community/en/stable/tutorials/quickstart.html', 'title': 'Quickstart - Manim Community v0.17.3'}), Document(page_content='Open a text editor, such as Notepad. Copy the following code snippet into the window:\n\nfrom manim import *\n\n\nclass CreateCircle(Scene):\n    def construct(self):\n        circle = Circle()  # create a circle\n        circle.set_fill(PINK, opacity=0.5)  # set the color and transparency\n        self.play(Create(circle))  # show the circle on screen\n\nSave the code snippet into your project folder with the name scene.py.\n\nproject/\n└─scene.py\n\n\n3. Open the command line, navigate to your project folder, and execute\nthe following command:\nmanim -pql scene.py CreateCircle\n\n\nManim will output rendering information, then create an MP4 file.\nYour default movie player will play the MP4 file, displaying the following animation.', metadata={'description': 'Overview: This quickstart guide will lead you through creating a sample project using Manim: an animation engine for precise programmatic animations. First, you will use a command line interface to...', 'language': 'en', 'source': 'https://docs.manim.community/en/stable/tutorials/quickstart.html', 'title': 'Quickstart - Manim Community v0.17.3'}), Document(page_content='Open a text editor, such as Notepad. Copy the following code snippet into the window:\n\nfrom manim import *\n\n\nclass CreateCircle(Scene):\n    def construct(self):\n        circle = Circle()  # create a circle\n        circle.set_fill(PINK, opacity=0.5)  # set the color and transparency\n        self.play(Create(circle))  # show the circle on screen\n\nSave the code snippet into your project folder with the name scene.py.\n\nproject/\n└─scene.py\n\n\n3. Open the command line, navigate to your project folder, and execute\nthe following command:\nmanim -pql scene.py CreateCircle\n\n\nManim will output rendering information, then create an MP4 file.\nYour default movie player will play the MP4 file, displaying the following animation.', metadata={'description': 'Overview: This quickstart guide will lead you through creating a sample project using Manim: an animation engine for precise programmatic animations. First, you will use a command line interface to...', 'language': 'en', 'source': 'https://docs.manim.community/en/stable/tutorials/quickstart.html', 'title': 'Quickstart - Manim Community v0.17.3'}), Document(page_content='self.play(Create(square))  # show the square on screen\n        self.play(square.animate.rotate(PI / 4))  # rotate the square\n        self.play(\n            ReplacementTransform(square, circle)\n        )  # transform the square into a circle\n        self.play(\n            circle.animate.set_fill(PINK, opacity=0.5)\n        )  # color the circle on screen\n\n\n\nRender AnimatedSquareToCircle by running the following command in the command line:\n\nmanim -pql scene.py AnimatedSquareToCircle\n\n\nThe following animation will r ...
